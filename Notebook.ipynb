# %% [markdown]
# Assigning values to variables

# %%
Students=100    #strength

# %%
Students
# Out:
# 100

# %%
pie=3.14

# %%
pie
# Out:
# 3.14

# %%
name='joshna'

# %%
name
# Out:
# 'joshna'

# %%
students=staff=26

# %%
staff
# Out:
# 26

# %%
students
# Out:
# 26

# %%
name=id='joshna'

# %%
id
# Out:
# 'joshna'

# %%
name='joshna'='pg'
# Out:
#   File "/tmp/ipykernel_60/483579468.py", line 1
#     name='joshna'='pg'
#         ^
# SyntaxError: can't assign to literal

# %% [markdown]
# STRINGS

# %%
Name= 'joshna_paute_gowda'

# %%
Name
# Out:
# 'joshna_paute_gowda'

# %%
Name[0]
# Out:
# 'j'

# %%
Name[10]
# Out:
# 't'

# %%
Name[0]
# Out:
# 'j'

# %%
Name[2:15]
# Out:
# 'shna_paute_go'

# %%
Name[2:]
# Out:
# 'shna_paute_gowda'

# %%
Name*2
# Out:
# 'joshna_paute_gowdajoshna_paute_gowda'

# %%
Name+'Amazon'+'joshna'
# Out:
# 'joshna_paute_gowdaAmazonjoshna'

# %%
Name[2]
# Out:
# 's'

# %% [markdown]
# Python Lists

# %%
List= ['joshna', 349, 509127, 29.3, '40l']

# %%
List[3]
# Out:
# 29.3

# %%
List[0,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_171/2610762011.py in <module>
# ----> 1 List[0,3]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
List[0:]
# Out:
# ['joshna', 349, 509127, 29.3, '40l']

# %%
List[1:]
# Out:
# [349, 509127, 29.3, '40l']

# %%
List[1:4]
# Out:
# [349, 509127, 29.3]

# %%
List[2:5]
# Out:
# [509127, 29.3, '40l']

# %%
List[4]
# Out:
# '40l'

# %%
List[4]= '1crore'

# %%
List[4]
# Out:
# '1crore'

# %%
List[0:]
# Out:
# ['joshna', 349, 509127, 29.3, '1crore']

# %%
List
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_263/3682665742.py in <module>
# ----> 1 List
#
# NameError: name 'List' is not defined

# %% [markdown]
# ### Tuple

# %%
Tuple = ('joshna', 349, 509127, 29.3, '1crore')

# %%
Tuple
# Out:
# ('joshna', 349, 509127, 29.3, '1crore')

# %%
Tuple(0:)
# Out:
#   File "/tmp/ipykernel_263/3760492276.py", line 1
#     Tuple(0:)
#            ^
# SyntaxError: invalid syntax

# %%
Tuple
# Out:
# ('joshna', 349, 509127, 29.3, '1crore')

# %%
Tuple[0]
# Out:
# 'joshna'

# %%
Tuple[3:]
# Out:
# (29.3, '1crore')

# %%
Tuple[4] = '2crore'
