# %% [markdown]
# Assigning values to variables

# %%
Students=100    #strength

# %%
Students
# Out:
# 100

# %%
pie=3.14

# %%
pie
# Out:
# 3.14

# %%
name='joshna'

# %%
name
# Out:
# 'joshna'

# %%
students=staff=26

# %%
staff
# Out:
# 26

# %%
students
# Out:
# 26

# %%
name=id='joshna'

# %%
id
# Out:
# 'joshna'

# %%
name='joshna'='pg'
# Out:
#   File "/tmp/ipykernel_60/483579468.py", line 1
#     name='joshna'='pg'
#         ^
# SyntaxError: can't assign to literal

# %% [markdown]
# STRINGS

# %%
Name= 'joshna_paute_gowda'

# %%
Name
# Out:
# 'joshna_paute_gowda'

# %%
Name[0]
# Out:
# 'j'

# %%
Name[10]
# Out:
# 't'

# %%
Name[0]
# Out:
# 'j'

# %%
Name[2:15]
# Out:
# 'shna_paute_go'

# %%
Name[2:]
# Out:
# 'shna_paute_gowda'

# %%
Name*2
# Out:
# 'joshna_paute_gowdajoshna_paute_gowda'

# %%
Name+'Amazon'+'joshna'
# Out:
# 'joshna_paute_gowdaAmazonjoshna'

# %%
Name[2]
# Out:
# 's'

# %% [markdown]
# Python Lists

# %%
List= ['joshna', 349, 509127, 29.3, '40l']

# %%
List[3]
# Out:
# 29.3

# %%
List[0,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_171/2610762011.py in <module>
# ----> 1 List[0,3]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
List[0:]
# Out:
# ['joshna', 349, 509127, 29.3, '40l']

# %%
List[1:]
# Out:
# [349, 509127, 29.3, '40l']

# %%
List[1:4]
# Out:
# [349, 509127, 29.3]

# %%
List[2:5]
# Out:
# [509127, 29.3, '40l']

# %%
List[4]
# Out:
# '40l'

# %%
List[4]= '1crore'

# %%
List[4]
# Out:
# '1crore'

# %%
List[0:]
# Out:
# ['joshna', 349, 509127, 29.3, '1crore']

# %%
List
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_263/3682665742.py in <module>
# ----> 1 List
#
# NameError: name 'List' is not defined

# %% [markdown]
# ### Tuple

# %%
Tuple = ('joshna', 349, 509127, 29.3, '1crore')

# %%
Tuple
# Out:
# ('joshna', 349, 509127, 29.3, '1crore')

# %%
Tuple(0:)
# Out:
#   File "/tmp/ipykernel_263/3760492276.py", line 1
#     Tuple(0:)
#            ^
# SyntaxError: invalid syntax

# %%
Tuple
# Out:
# ('joshna', 349, 509127, 29.3, '1crore')

# %%
Tuple[0]
# Out:
# 'joshna'

# %%
Tuple[3:]
# Out:
# (29.3, '1crore')

# %%
Tuple[4] = '2crore'

# %%
a = 2

# %%
b = 3

# %%
if (a==b):
# Out:
#   File "/tmp/ipykernel_61/1725628685.py", line 1
#     if (a==b):
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
a = 3
b = 4
if (a==b):
    print (" line- a is equal to b ")
else:
    print ("line- a is not equal to b ")
# Out:
# line- a is not equal to b

# %%
if (a!=b):
    print (" line-a is not equal to b")
else:
    print(" line-a is equal to b")
# Out:
#  line-a is not equal to b

# %%
if (a<b):
    print(" line- a is less than b ")
else:
    print( "line- a is not less than b ")
# Out:
#  line- a is less than b

# %%
a,b=b,a

# %%
if(a<=b):
    print( "line- a is either less than or equal to b")
else:
    print( "line-a is neither less than nor equal to b")
# Out:
# line-a is neither less than nor equal to b

# %%
a = 89
b = 64
if (a==b):
    print (" line- a is equal to b ")
else:
    print ("line- a is not equal to b ")
if (a!=b):
    print (" line-a is not equal to b")
else:
    print(" line-a is equal to b")
if (a<b):
    print(" line- a is less than b ")
else:
    print( "line- a is not less than b ")
    a,b=b,a
if(a<=b):
    print( "line- a is either less than or equal to b")
else:
    print( "line-a is neither less than nor equal to b")
# Out:
# line- a is not equal to b
#  line-a is not equal to b
# line- a is not less than b
# line- a is either less than or equal to b

# %% [markdown]
# Flip coin game

# %%
import random

guess = ''

while guess not in ('Heads', 'Tails'):
  print('Guess the toss, Enter Tails or Heads')
  guess = input()
toss = random.randint(0,1)
if toss==guess:
 print('you guessed it right')
else:
  print('try again!')
  guesss = input()
  if toss==guess:
     print('you guessed it right')
  else:
      print('You are bad at this!')
# Out:
# Guess the toss, Enter Tails or Heads

# %%
import random

guess = ''
while guess not in ('heads', 'tails'):
    print('Guess the coin toss! Enter heads or tails:')
    guess = input()
toss = random.randint(0, 1) # 0 is tails, 1 is heads
if toss == guess:
    print('You got it!')
else:
    print('Nope! Guess again!')
    guesss = input()
    if toss == guess:
       print('You got it!')
    else:
        print('Nope. You are really bad at this game.')

# %%
import random

guess = ''
while guess not in ('heads', 'tails'):
    print('Guess the coin toss! Enter heads or tails:')
    guess = input()
toss = random.randint(0, 1) # 0 is tails, 1 is heads
if toss == guess:
    print('You got it!')
else:
    print('Nope! Guess again!')
    guesss = input()
    if toss == guess:
       print('You got it!')
    else:
        print('Nope. You are really bad at this game.')
# Out:
# Guess the coin toss! Enter heads or tails:
#  heads
# Nope! Guess again!
#  tails
# Nope. You are really bad at this game.
